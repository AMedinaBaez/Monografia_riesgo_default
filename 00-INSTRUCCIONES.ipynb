# %% [markdown]
# # **Aplicación de técnicas de machine learning para la predicción del riesgo de default de un cliente en una compañía de filipinas**
#
# Realizado por:
#
# * Andrés Medina Báez       cc 1036654885
# * Manuela Ramírez Quiceno  cc 1037657504

# %% [markdown]
# # **1.Introducción**

# %% [markdown]
# Home Credit es una empresa de filipinas que busca ofrecer créditos a personas con antecedentes crediticios insuficientes o inexistentes, buscando la inclusión financiera de la población no bancarizada.
#
# Para ello, esta compañía busca utilizar información transaccional y de telecomunicaciones, con el fin de predecir el riesgo de default de sus clientes.

# %% [markdown]
# **Principal Objetivo**: ¿Al cliente, le debo o no de otorgar el préstamo a partir de su riesgo de default?

# %% [markdown]
# **Variable Objetivo**: Probabilidad de que el cliente presente retrasos en el pago de su cuota  (1) o no (0)

# %% [markdown]
# En este proyecto se realizaron 8 iteraciones diferentes, correspondiente a los 8 notebooks los cuales su nombre inicia con "Modelacion_corrida..."
#
#
#
# *   Iteración 1: 05-Modelacion_corrida1.ipynb
#
# *   Iteración 2: 10-Modelacion_corrida_82cols.ipynb
#
# *   Iteración 3: 13_Modelacion_corrida_62cols.ipynb
#
# *   Iteración 4: 16-Modelacion_corrida_60Cols.ipynb
#
# *   Iteración 5: 17-Modelacion_corrida_60Cols_scaler.ipynb
#
# *   Iteración 6: 18-Modelacion_corrida2_15Cols_imbalance.ipynb
#
# *   Iteración 7: 19-Modelacion_corrida2_15Cols_balanced_over.ipynb
#
# *   Iteración 8: 20-Modelacion_corrida2_15Cols_balanced_sub.ipynb

# %% [markdown]
# **Los mejores resultados del proyecto, serán mostrados en el notebook " " para no tener que ejecutar la totalidad de los archivos.**

# %% [markdown]
# # **2. Contenido del repositorio**

# %% [markdown]
# 01-Carga_datos_1ra_Iter.ipynb
#
# 02-DF_Final_1ra_Iter.csv
#
# 03-Limpieza_Datos_1ra_Iter.ipynb
#
# 04-DF_Final_2_1ra_Iter.csv
#
# 05-Modelacion_corrida1.ipynb
#
# 06-Carga_datos_Final.ipynb
#
# 07-DF_Inicial.csv
#
# 08-Limpieza_Datos_82Cols.ipynb
#
# 09-DF_Final_82cols.csv
#
# 10-Modelacion_corrida_82cols.ipynb
#
# 11-Limpieza_Datos_62cols.ipynb
#
# 12-DF_Final_62cols.csv
#
# 13_Modelacion_corrida_62cols.ipynb
#
# 14-Preprocesamiento_Data_Elegida.ipynb
#
# 15-DF_Final_60cols.csv
#
# 16-Modelacion_corrida_60Cols.ipynb
#
# 17-Modelacion_corrida_60Cols_scaler.ipynb
#
# 18-Modelacion_corrida2_15Cols_imbalance.ipynb
#
# 19-Modelacion_corrida2_15Cols_balanced_over.ipynb
#
# 20-Modelacion_corrida2_15Cols_balanced_sub.ipynb
#
# 21-Resultado_Final.ipynb

# %% [markdown]
# # **3. Instrucciones de uso de los notebooks**

# %% [markdown]
# En este repositorio se encontrará nuestra solución al reto de kaggle (https://www.kaggle.com/c/home-credit-default-risk).
#
# A continuación, se dejará una descripción general de cada archivo mencionado en el contenido y las recomendaciones a tener en cuenta para su buena ejecución.

# %% [markdown]
# ## **3.01-Carga_datos_1ra_Iter.ipynb**

# %% [markdown]
# ### **3.01.1.Descripción del notebook**

# %% [markdown]
# Este notebook hace parte de la primera iteración, a través de este se realiza la descarga de los datos del proyecto desde kaggle, como son diferentes archivos, se realizan sobre cada uno de los archivos las transformaciones convenientes para finalmente unir las diferentes datas en una sola, generando así, el archivo llamado "02-DF_Final_1ra_Iter.csv".

# %% [markdown]
# ### **3.01.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este primer notebook es importante tener presente varias observaciones:
#
# 1. Se debe hacer la conexión entre la api de kaggle y colab, para esto es necesario descargar el Token que genera kaggle. Este se genera como un archivo llamado **kaggle.json**, el cual debe ser cargado en colab, en la línea con código: **files.upload()**. (https://www.youtube.com/watch?v=T8xEQI8XXGs en este video muestran como generar el kaggle.json)
#
# 2. En la línea de código: **!kaggle competitions download -c home-credit-default-risk**, se hace la descarga del archivo o archivos, estos se descargan en uno o varios archivos .zip, por tanto al correr esta línea, hay que percatarse que el o los archivos que se descargan si sean los correspondiente a los que se descomprimen en la línea de código siguiente: ***! unzip home-credit-default-risk.zip ***, sino, debe cambiarse el nombre por el o los .zip que aparezcan en colab.

# %% [markdown]
# ## **3.02-DF_Final_1ra_Iter.csv**

# %% [markdown]
# ### **3.02.1.Descripción del notebook**

# %% [markdown]
# Este archivo .csv hace parte de la primera iteración, es la data ya contenida en un solo archivo, cuenta con 183 variables y 307511 registros.

# %% [markdown]
# ### **3.02.2.Recomendaciones para la ejecución**

# %% [markdown]
# Esta data aún no tiene procesamiento y limpieza de los datos, por ende, solo se usará en el notebook "03-Limpieza_Datos_1ra_Iter.ipynb" para ser cargada y transformada en otra data.

# %% [markdown]
# ## **3.03-Limpieza_Datos_1ra_Iter.ipynb**

# %% [markdown]
# ### **3.03.1.Descripción del notebook**

# %% [markdown]
# Este notebook hace parte de la primera iteración, a través de este se realiza la limpieza y procesamiento de los datos. En este procesamiento y limpieza se aplica:
#
#
#
# *   Eliminación de registros dupliacdos y variables redundantes
# *   Codificación de variables categóricas
# * Tratamiento de missing o datos nulos
# * Tratamiento de outliers o valores atípicos
# * Análisis de variables númericas y categóricas

# %% [markdown]
# ### **3.03.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este notebook es importante tener presente varias observaciones:
#
# 1. El archivo de entrada es "02-DF_Final_1ra_Iter.csv", este se debe cargar.
#
# 2. Este notebook genera un archivo de salida, el cual será la transformación, procesamiento y limpieza de la data de entrada, el nombre del archivo generado es "04-DF_Final_2_1ra_Iter.csv"

# %% [markdown]
# ## **3.04-DF_Final_2_1ra_Iter.csv**

# %% [markdown]
# ### **3.04.1.Descripción del notebook**

# %% [markdown]
# Este archivo .csv hace parte de la primera iteración, es la data de entrada con la que se hace el modelamiento. Esta consta de 72 variables y 302851 registros.

# %% [markdown]
# ### **3.04.2.Recomendaciones para la ejecución**

# %% [markdown]
# Por ser la primera iteración, la data se procesó sin tener algunos conocimientos de algunos temas posteriores a la realización de dicha iteración, por ende, esta data, solo será usada para estos primeros modelos.

# %% [markdown]
# ## **3.05-Modelacion_corrida1.ipynb**

# %% [markdown]
# ### **3.05.1.Descripción del notebook**

# %% [markdown]
# Este notebook hace parte de la primera iteración, aquí se realiza el modelamiento y evaluación de los modelos:
#
#
#
# *   Regresión logística
# *   Naive Bayes
# * Árbol de decisión

# %% [markdown]
# ### **3.05.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este notebook es importante tener presente varias observaciones:
#
# 1. El archivo de entrada es "04-DF_Final_2_1ra_Iter.csv", este se debe cargar.

# %% [markdown]
# ## **3.06-Carga_datos_Final.ipynb**

# %% [markdown]
# ### **3.06.1.Descripción del notebook**

# %% [markdown]
# En este notebook se realiza la descarga de los datos del proyecto desde kaggle, como son diferentes archivos, se realizan sobre cada uno de los archivos las transformaciones convenientes para finalmente unir las diferentes datas en una sola, generando así, el archivo llamado "07-DF_Inicial.csv".

# %% [markdown]
# ### **3.06.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este notebook es importante tener presente varias observaciones:
#
# 1. Se debe hacer la conexión entre la api de kaggle y colab, para esto es necesario descargar el Token que genera kaggle. Este se genera como un archivo llamado **kaggle.json**, el cual debe ser cargado en colab, en la línea con código: **files.upload()**. (https://www.youtube.com/watch?v=T8xEQI8XXGs en este video muestran como generar el kaggle.json)
#
# 2. En la línea de código: **!kaggle competitions download -c home-credit-default-risk**, se hace la descarga del archivo o archivos, estos se descargan en uno o varios archivos .zip, por tanto al correr esta línea, hay que percatarse que el o los archivos que se descargan si sean los correspondiente a los que se descomprimen en la línea de código siguiente: ***! unzip home-credit-default-risk.zip ***, sino, debe cambiarse el nombre por el o los .zip que aparezcan en colab.

# %% [markdown]
# ## **3.07-DF_Inicial.csv**

# %% [markdown]
# ### **3.07.1.Descripción del notebook**

# %% [markdown]
# Este archivo .csv es la data ya contenida en un solo archivo, cuenta con 248 variables y 307511 registros.

# %% [markdown]
# ### **3.07.2.Recomendaciones para la ejecución**

# %% [markdown]
# Esta data aún no tiene procesamiento y limpieza de los datos, por ende, solo se usará en los notebooks "08-Limpieza_Datos_82Cols.ipynb" y "11-Limpieza_Datos_62cols.ipynb" para ser cargada y transformada en otra data.

# %% [markdown]
# ## **3.08-Limpieza_Datos_82Cols.ipynb**

# %% [markdown]
# ### **3.08.1.Descripción del notebook**

# %% [markdown]
# En este notebook se realiza la limpieza y procesamiento de los datos. En este procesamiento y limpieza se aplica:
#
#
# * Algunas transformaciones de variables
# *   Eliminación de registros dupliacdos y variables redundantes
# *   Codificación de variables categóricas
# * Tratamiento de missing o datos nulos
# * Tratamiento de outliers o valores atípicos
# * Análisis de variables númericas y categóricas

# %% [markdown]
# ### **3.08.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este notebook es importante tener presente varias observaciones:
#
# 1. El archivo de entrada es "07-DF_Inicial.csv", este se debe cargar.
#
# 2. Este notebook genera un archivo de salida, el cual será la transformación, procesamiento y limpieza de la data de entrada, el nombre del archivo generado es "09-DF_Final_82cols.csv"

# %% [markdown]
# ## **3.09-DF_Final_82cols.csv**

# %% [markdown]
# ### **3.09.1.Descripción del notebook**

# %% [markdown]
# Este archivo .csv es la data ya contenida en un solo archivo, cuenta con 82 variables y 295237 registros.

# %% [markdown]
# ### **3.09.2.Recomendaciones para la ejecución**

# %% [markdown]
# 1.Este data solo se usará en el notebook "10-Modelacion_corrida_82cols.ipynb", ya que posteriormente, se realiza un mejor preprocesamiento de la data inicial "07-DF_Inicial.csv"

# %% [markdown]
# ## **3.10-Modelacion_corrida_82cols.ipynb**

# %% [markdown]
# ### **3.10.1.Descripción del notebook**

# %% [markdown]
# En este notebook se realiza el modelamiento y evaluación de los modelos:
#
#
#
# *   Regresión logística
# *   Naive Bayes
# * Árbol de decisión

# %% [markdown]
# ### **3.10.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este notebook es importante tener presente varias observaciones:
#
# 1. El archivo de entrada es "09-DF_Final_82cols.csv", este se debe cargar.

# %% [markdown]
# ## **3.11-Limpieza_Datos_82Cols.ipynb**

# %% [markdown]
# ### **3.11.1.Descripción del notebook**

# %% [markdown]
# En este notebook se realiza la limpieza y procesamiento de los datos. En este procesamiento y limpieza se aplica:
#
#
# * Algunas transformaciones de variables
# *   Eliminación de registros dupliacdos y variables redundantes
# *   Codificación de variables categóricas
# * Tratamiento de missing o datos nulos
# * Tratamiento de outliers o valores atípicos
# * Análisis de variables númericas y categóricas

# %% [markdown]
# ### **3.11.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este notebook es importante tener presente varias observaciones:
#
# 1. El archivo de entrada es "07-DF_Inicial.csv", este se debe cargar.
#
# 2. Este notebook genera un archivo de salida, el cual será la transformación, procesamiento y limpieza de la data de entrada, el nombre del archivo generado es "12-DF_Final_62cols.csv"

# %% [markdown]
# ## **3.12-DF_Final_62cols.csv**

# %% [markdown]
# ### **3.12.1.Descripción del notebook**

# %% [markdown]
# Este archivo .csv es la data ya contenida en un solo archivo, cuenta con 62 variables y 295237 registros.

# %% [markdown]
# ### **3.12.2.Recomendaciones para la ejecución**

# %% [markdown]
# 1.Este data solo se usará en el notebook "13_Modelacion_corrida_62cols.ipynb", ya que posteriormente, se realiza un mejor preprocesamiento de la data inicial "07-DF_Inicial.csv"

# %% [markdown]
# ## **3.13_Modelacion_corrida_62cols.ipynb**

# %% [markdown]
# ### **3.13.1.Descripción del notebook**

# %% [markdown]
# En este notebook se realiza el modelamiento y evaluación de los modelos:
#
#
#
# *   Regresión logística
# *   Naive Bayes
# * Árbol de decisión

# %% [markdown]
# ### **3.13.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este notebook es importante tener presente varias observaciones:
#
# 1. El archivo de entrada es "12-DF_Final_62cols.csv", este se debe cargar.

# %% [markdown]
# ## **3.14-Preprocesamiento_Data_Elegida.ipynb**

# %% [markdown]
# ### **3.14.1.Descripción del notebook**

# %% [markdown]
# En este notebook se realiza la limpieza y procesamiento de los datos. En este procesamiento y limpieza se aplica:
#
#
# * Algunas transformaciones de variables
# *   Eliminación de registros dupliacdos y variables redundantes
# *   Codificación de variables categóricas
# * Tratamiento de missing o datos nulos
# * Tratamiento de outliers o valores atípicos
# * Análisis de variables númericas y categóricas

# %% [markdown]
# ### **3.14.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este notebook es importante tener presente varias observaciones:
#
# 1. El archivo de entrada es "12-DF_Final_62cols.csv", este se debe cargar.
#
# 2. Este notebook genera un archivo de salida, el cual será la transformación, procesamiento y limpieza de la data de entrada, el nombre del archivo generado es "15-DF_Final_60cols.csv". Este es la data final ya procesada.

# %% [markdown]
# ## **3.15-DF_Final_60cols.csv**

# %% [markdown]
# ### **3.15.1.Descripción del notebook**

# %% [markdown]
# Este archivo .csv es la data ya contenida en un solo archivo, cuenta con 60 variables y 295221 registros.

# %% [markdown]
# ### **3.15.2.Recomendaciones para la ejecución**

# %% [markdown]
# 1.Este data se usará en los demas notebooks, ya que, es la data elegida como data final.

# %% [markdown]
# ## **3.16-Modelacion_corrida_60Cols.ipynb**

# %% [markdown]
# ### **3.16.1.Descripción del notebook**

# %% [markdown]
# En este notebook se realiza el modelamiento y evaluación de los modelos:
#
#
#
# *   Regresión logística
# *   Naive Bayes
# * Árbol de decisión
# * Random Forest
#
# En esta iteración se usa el data de 60 variables.

# %% [markdown]
# ### **3.16.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este notebook es importante tener presente varias observaciones:
#
# 1. El archivo de entrada es "15-DF_Final_60cols.csv", este se debe cargar.

# %% [markdown]
# ## **3.17-Modelacion_corrida_60Cols_scaler.ipynb**

# %% [markdown]
# ### **3.17.1.Descripción del notebook**

# %% [markdown]
# En este notebook se realiza el modelamiento y evaluación de los modelos:
#
#
#
# *   Regresión logística
# *   Naive Bayes
# * Árbol de decisión
# * Random Forest
#
# En esta iteración se usa el data de 60 variables, pero se le aplica escalamiento a las variables numéricas.

# %% [markdown]
# ### **3.17.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este notebook es importante tener presente varias observaciones:
#
# 1. El archivo de entrada es "15-DF_Final_60cols.csv", este se debe cargar.

# %% [markdown]
# ## **3.18-Modelacion_corrida2_15Cols_imbalance.ipynb**

# %% [markdown]
# ### **3.18.1.Descripción del notebook**

# %% [markdown]
# En este notebook se realiza el modelamiento y evaluación de los modelos:
#
#
#
# *   Regresión logística
# *   Naive Bayes
# * Árbol de decisión
# * Random Forest
#
# En esta iteración se usa el data de 60 variables, pero se modifica sacando las mejores 15 variables de la data, en esta iteración no se hace ningún tipo de smote. A partir de esta iteración se calculan hiperparámetros para los modelos.

# %% [markdown]
# ### **3.18.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este notebook es importante tener presente varias observaciones:
#
# 1. El archivo de entrada es "15-DF_Final_60cols.csv", este se debe cargar.

# %% [markdown]
# ## **3.19-Modelacion_corrida2_15Cols_balanced_over.ipynb**

# %% [markdown]
# ### **3.19.1.Descripción del notebook**

# %% [markdown]
# En este notebook se realiza el modelamiento y evaluación de los modelos:
#
#
#
# *   Regresión logística
# *   Naive Bayes
# * Árbol de decisión
# * Random Forest
#
# En esta iteración se usa el data de 60 variables, pero se modifica sacando las mejores 15 variables de la data, en esta iteración se hace smote creando registros sintéticos para que la clase con menor cantidad de datos quedara con la misma cantidad de datos que la otra clase. En esta iteración se calculan hiperparámetros para los modelos.

# %% [markdown]
# ### **3.19.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este notebook es importante tener presente varias observaciones:
#
# 1. El archivo de entrada es "15-DF_Final_60cols.csv", este se debe cargar.

# %% [markdown]
# ## **3.20-Modelacion_corrida2_15Cols_balanced_sub.ipynb**

# %% [markdown]
# ### **3.20.1.Descripción del notebook**

# %% [markdown]
# En este notebook se realiza el modelamiento y evaluación de los modelos:
#
#
#
# *   Regresión logística
# *   Naive Bayes
# * Árbol de decisión
# * Random Forest
#
# En esta iteración se usa el data de 60 variables, pero se modifica sacando las mejores 15 variables de la data, en esta iteración se hace smote desechando información de la clase con mayor registros, de tal forma que, quedara con la misma cantidad de registros que la otra clase. En esta iteración se calculan hiperparámetros para los modelos.

# %% [markdown]
# ### **3.20.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este notebook es importante tener presente varias observaciones:
#
# 1. El archivo de entrada es "15-DF_Final_60cols.csv", este se debe cargar.

# %% [markdown]
# ## **3.21-Resultado_Final.ipynb**

# %% [markdown]
# ### **3.21.1.Descripción del notebook**

# %% [markdown]
# En este notebook se realiza el resumen y conclusiones de los 3 modelos que mostraron mejores resultados.
# Estos modelos son:
# * Regresión Logística, imbalanced, parametros óptimizados = Default
# * Regresión Logística, Con SMOTE por debajo, parametros óptimizados
# * Random Forest, Con SMOTE por debajo, parametros óptimizados

# %% [markdown]
# ### **3.20.2.Recomendaciones para la ejecución**

# %% [markdown]
# En este notebook es importante tener presente varias observaciones:
#
# 1. El archivo de entrada es "15-DF_Final_60cols.csv", este se debe cargar.
