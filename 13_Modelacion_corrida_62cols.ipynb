# %% [markdown]
# # **Aplicación de técnicas de machine learning para la predicción del riesgo de default de un cliente en una compañía de filipinas**
#
# Realizado por:
#
# * Andrés Medina Báez       cc 1036654885
# * Manuela Ramírez Quiceno  cc 1037657504

# %% [markdown]
# # 1.Introducción

# %% [markdown]
# Home Credit es una empresa de filipinas que busca ofrecer créditos a personas con antecedentes crediticios insuficientes o inexistentes, buscando la inclusión financiera de la población no bancarizada.
#
# Para ello, esta compañía busca utilizar información transaccional y de telecomunicaciones, con el fin de predecir el riesgo de default de sus clientes.
#
#
# **Principal Objetivo**: ¿Al cliente, le debo o no de otorgar el préstamo a partir de su riesgo de default?
#
#
# **Variable Objetivo**: Probabilidad de que el cliente presente retrasos en el pago de su cuota  (1) o no (0)

# %% [markdown]
# # 2.Importar librerias

# %% [markdown]
# Las librerías a usar en la carga de los datos son:
#
#
#
# *   pandas: Para cargar los datos en dataframes.
# *   numpy: Para operaciones con matrices, filas y/o columnas
# *   matplotlib: Para graficar
# *   os: Para interactuar con diferentes rutas
# *plotly: Para graficar la matriz de correlación
# *sklearn: Para hacer la separación de la data en train y test, y para los modelos de ML y las métricas de evaluación.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
from sklearn import model_selection
import plotly.express as px
# Evaluation
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import plot_precision_recall_curve
# Selected algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # 3.Cargar la Data

# %% [markdown]
# Se carga el archivo de salida del notebook 11-Limpieza_Datos_62cols.ipynb

# %%
data = pd.read_csv("12-DF_Final_62cols.csv",index_col=0) # Read data
data_original=data.copy()
data.head(5)
# Out:
#    SK_ID_CURR  TARGET  FLAG_OWN_CAR  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0      100002       1             0           0.0          202500.0
# 1      100003       0             0           0.0          270000.0
# 2      100004       0             1           0.0           67500.0
# 3      100006       0             0           0.0          135000.0
# 4      100007       0             0           0.0          121500.0
#
#    AMT_CREDIT_x  DAYS_BIRTH  MONTHS_EMPLOYED  REGION_RATING_CLIENT_W_CITY  \
# 0      406597.5        26.0             21.0                            2
# 1     1293502.5        46.0             40.0                            1
# 2      135000.0        52.0              8.0                            2
# 3      312682.5        52.0            101.0                            2
# 4      513000.0        55.0            101.0                            2
#
#    EXT_SOURCE_2  ...  NAME_PORTFOLIO_Cash  NAME_PORTFOLIO_POS  \
# 0      0.262949  ...                  0.0                 1.0
# 1      0.622246  ...                  1.0                 2.0
# 2      0.555912  ...                  0.0                 1.0
# 3      0.650442  ...                  3.0                 2.0
# 4      0.322738  ...                  4.0                 2.0
#
#    NAME_PRODUCT_TYPE_walk-in  ind_vel_monto_cr  WALLSMATERIAL_MODE_DUROS  \
# 0                        0.0          1.000000                         1
# 1                        0.0          1.000000                         1
# 2                        0.0          1.000000                         0
# 3                        0.0          1.000000                         0
# 4                        1.0          1.037038                         0
#
#    WALLSMATERIAL_MODE_ARMABLES  OCCUPATION_TYPE_BAJO  OCCUPATION_TYPE_MEDIO  \
# 0                            0                     1                      0
# 1                            0                     0                      1
# 2                            0                     1                      0
# 3                            0                     1                      0
# 4                            0                     0                      1
#
#    OCCUPATION_TYPE_ALTO  indice_falta_pagar
# 0                     0            0.284122
# 1                     0            0.000000
# 2                     0            0.000000
# 3                     0            0.000000
# 4                     0            0.000000
#
# [5 rows x 62 columns]

# %%
data.replace([np.inf, -np.inf], np.nan,inplace=True)

# %%
data['indice_falta_pagar']=data['indice_falta_pagar'].replace(np.nan,0)

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 295237 entries, 0 to 295236
# Data columns (total 62 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   SK_ID_CURR                                         295237 non-null  int64
#  1   TARGET                                             295237 non-null  int64
#  2   FLAG_OWN_CAR                                       295237 non-null  int64
#  3   CNT_CHILDREN                                       295237 non-null  float64
#  4   AMT_INCOME_TOTAL                                   295237 non-null  float64
#  5   AMT_CREDIT_x                                       295237 non-null  float64
#  6   DAYS_BIRTH                                         295237 non-null  float64
#  7   MONTHS_EMPLOYED                                    295237 non-null  float64
#  8   REGION_RATING_CLIENT_W_CITY                        295237 non-null  int64
#  9   EXT_SOURCE_2                                       295237 non-null  float64
#  10  DEF_30_CNT_SOCIAL_CIRCLE                           295237 non-null  float64
#  11  DEF_60_CNT_SOCIAL_CIRCLE                           295237 non-null  float64
#  12  NAME_INCOME_TYPE_Businessman                       295237 non-null  int64
#  13  NAME_INCOME_TYPE_Commercial associate              295237 non-null  int64
#  14  NAME_INCOME_TYPE_Others                            295237 non-null  int64
#  15  NAME_INCOME_TYPE_Pensioner                         295237 non-null  int64
#  16  NAME_INCOME_TYPE_State servant                     295237 non-null  int64
#  17  NAME_INCOME_TYPE_Working                           295237 non-null  int64
#  18  NAME_EDUCATION_TYPE_Higher education               295237 non-null  int64
#  19  NAME_EDUCATION_TYPE_Incomplete higher              295237 non-null  int64
#  20  NAME_EDUCATION_TYPE_Lower secondary                295237 non-null  int64
#  21  NAME_EDUCATION_TYPE_Secondary / secondary special  295237 non-null  int64
#  22  NAME_HOUSING_TYPE_House / apartment                295237 non-null  int64
#  23  NAME_HOUSING_TYPE_Rented apartment                 295237 non-null  int64
#  24  NAME_HOUSING_TYPE_With parents                     295237 non-null  int64
#  25  FONDKAPREMONT_MODE_org spec account                295237 non-null  int64
#  26  FONDKAPREMONT_MODE_reg oper account                295237 non-null  int64
#  27  FONDKAPREMONT_MODE_reg oper spec account           295237 non-null  int64
#  28  HOUSETYPE_MODE_block of flats                      295237 non-null  int64
#  29  HOUSETYPE_MODE_specific housing                    295237 non-null  int64
#  30  WALLSMATERIAL_MODE_Others                          295237 non-null  int64
#  31  DAYS_CREDIT                                        295237 non-null  float64
#  32  AMT_CREDIT_SUM_OVERDUE                             295237 non-null  float64
#  33  DAYS_CREDIT_UPDATE                                 295237 non-null  float64
#  34  CREDIT_ACTIVE_Active                               295237 non-null  float64
#  35  CREDIT_ACTIVE_Closed                               295237 non-null  float64
#  36  CREDIT_TYPE_Another type of loan                   295237 non-null  float64
#  37  CREDIT_TYPE_Consumer credit                        295237 non-null  float64
#  38  CREDIT_TYPE_Microloan                              295237 non-null  float64
#  39  CREDIT_TYPE_Mortgage                               295237 non-null  float64
#  40  AMT_ANNUITY                                        295237 non-null  float64
#  41  RATE_DOWN_PAYMENT                                  295237 non-null  float64
#  42  AMT_DOWN_PAYMENT                                   295237 non-null  float64
#  43  CNT_PAYMENT                                        295237 non-null  float64
#  44  DAYS_DECISION                                      295237 non-null  float64
#  45  DAYS_FIRST_DRAWING                                 295237 non-null  float64
#  46  DAYS_TERMINATION                                   295237 non-null  float64
#  47  NAME_CONTRACT_STATUS_Approved                      295237 non-null  float64
#  48  NAME_CONTRACT_STATUS_Canceled                      295237 non-null  float64
#  49  NAME_CONTRACT_STATUS_Refused                       295237 non-null  float64
#  50  NAME_CLIENT_TYPE_New                               295237 non-null  float64
#  51  NAME_PORTFOLIO_Cards                               295237 non-null  float64
#  52  NAME_PORTFOLIO_Cash                                295237 non-null  float64
#  53  NAME_PORTFOLIO_POS                                 295237 non-null  float64
#  54  NAME_PRODUCT_TYPE_walk-in                          295237 non-null  float64
#  55  ind_vel_monto_cr                                   295237 non-null  float64
#  56  WALLSMATERIAL_MODE_DUROS                           295237 non-null  int64
#  57  WALLSMATERIAL_MODE_ARMABLES                        295237 non-null  int64
#  58  OCCUPATION_TYPE_BAJO                               295237 non-null  int64
#  59  OCCUPATION_TYPE_MEDIO                              295237 non-null  int64
#  60  OCCUPATION_TYPE_ALTO                               295237 non-null  int64
#  61  indice_falta_pagar                                 295237 non-null  float64
# dtypes: float64(34), int64(28)
# memory usage: 141.9 MB

# %%
data.drop(columns=['SK_ID_CURR'],inplace=True)

# %%
len(data.columns)
# Out:
# 61

# %%
data['TARGET']=data['TARGET'].astype('category')
data['TARGET'].dtype
# Out:
# CategoricalDtype(categories=[0, 1], ordered=False)

# %% [markdown]
# # 4.Partición de la data en train y test

# %% [markdown]
# Teniendo en cuenta que nos estamos enfrentando a un problema de data desbalanceada, se realiza la partición garantizando un muestreo estratificado para la variable TARGET

# %%
X = data.drop("TARGET", axis=1)
y= data["TARGET"]

# %%
X.shape, y.shape
# Out:
# ((295237, 60), (295237,))

# %% [markdown]
# ## Split dataset 70/30

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3,random_state =42, stratify=y)

# %%
perc_test = y_test.value_counts()[1]*100/len(y_test)
perc_train = y_train.value_counts()[1]*100/len(y_train)

print(f"Porcentaje de muestras positivas en el dataset de test={round(perc_test,4)} , y de test={round(perc_train,4)}")
# Out:
# Porcentaje de muestras positivas en el dataset de test=8.0748 , y de test=8.0754

# %% [markdown]
# # 5.Selección de la métrica de desempeño del modelo

# %% [markdown]
# Selección de la métrica de evaluación:
#
# En el reto de kaggle piden que la métrica de evaluación sea el área ROC.
#
#
# El error que más le cuesta al modelo son aquellos clientes que marca como 0, es decir, que no caerán en default, pero en realidad, son un 1. Por esta razón, se busca minimizar el error correspondiente al FN: Falsos Negativos.
#
# > Recall - Sensitivity
#
# (Puede ser recall o F1)
#
# En este caso, un falso negativo tiene un mayor costo en términos de capital que no retorna al banco Home Credit y le toca provisionar y pagar, vs un falso positivo, que son clientes que por el perfil de riesgo adoptado por Home Credit, puede al final tomar la decisión en una etapa posterior si en efecto se debe rechazar al cliente por el resultado del modelo [target = 1], o no.

# %% [markdown]
# # 6.Selección de Modelos

# %% [markdown]
# ## 6.1. Modelar

# %% [markdown]
# Para esta iteración se modelará el problema con un modelo de regresión logística, un arbol de decisión y un naive bayes.

# %% [markdown]
# ### 6.1.1 Regresión Logistica

# %%
rl=LogisticRegression(solver='liblinear')
rl.fit(X_train,y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %% [markdown]
# ### 6.1.2 Árbol de Decisión

# %%
dtc=DecisionTreeClassifier(criterion='entropy',random_state=0)
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %% [markdown]
# ### 6.1.3 Naive Bayes

# %%
gnb=GaussianNB()
gnb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ### 6.1.4 Predicción del Modelo

# %%
#Regresion
y_dtc_pred=dtc.predict(X_test)
y_rl_pred=rl.predict(X_test)
y_gnb_pred=gnb.predict(X_test)

# %%
### 2.1.4. Evaluación de los Modelos
print('Accuracy')
print('-------------------------------------------------------------------------------------------------')
print(f"Decision Tree Classifier : Score_entrenamiento:{round(dtc.score(X_train, y_train),4)},    & Score_validacion:{round(accuracy_score(y_test,y_dtc_pred),4)}")
print(f"Logistic Regresion       : Score_entrenamiento:{round(rl.score(X_train, y_train),4)}, & Score_validacion:{round(accuracy_score(y_test,y_rl_pred),4)}")
print(f"Naive Bayes              : Score_entrenamiento:{round(gnb.score(X_train, y_train),4)},  & Score_validacion:{round(accuracy_score(y_test,y_gnb_pred),4)}\n")


print('Recall')
print('-------------------------------------------------------------------------------------------------')
print(f"Decision Tree Classifier : Recall_validacion:{1-round(recall_score(y_test,y_dtc_pred),4)}")
print(f"Logistic Regresion       : Recall_validacion:{1-round(recall_score(y_test,y_rl_pred),4)}")
print(f"Naive Bayes              : Recall_validacion:{1-round(recall_score(y_test,y_gnb_pred),4)}")
# Out:
# Accuracy
# -------------------------------------------------------------------------------------------------
# Decision Tree Classifier : Score_entrenamiento:1.0,    & Score_validacion:0.8547
# Logistic Regresion       : Score_entrenamiento:0.9192, & Score_validacion:0.9192
# Naive Bayes              : Score_entrenamiento:0.9159,  & Score_validacion:0.9158
#
# Recall
# -------------------------------------------------------------------------------------------------
# Decision Tree Classifier : Recall_validacion:0.8476
# Logistic Regresion       : Recall_validacion:0.9999
# Naive Bayes              : Recall_validacion:0.9843

# %%
#Classification Report para los modelos 
print(f"Logistic Regresion  Results:\n" 
      f"{classification_report(y_test,y_rl_pred)}\n")

print(f"Naive Bayes Results:\n" 
      f"{classification_report(y_test,y_gnb_pred)}\n")
print(f"Decision tree Results:\n" 
      f"{classification_report(y_test,y_dtc_pred)}\n")
# Out:
# Logistic Regresion  Results:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     81420
#            1       0.33      0.00      0.00      7152
#
#     accuracy                           0.92     88572
#    macro avg       0.63      0.50      0.48     88572
# weighted avg       0.87      0.92      0.88     88572
#
#
# Naive Bayes Results:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96     81420
#            1       0.21      0.02      0.03      7152
#
#     accuracy                           0.92     88572
#    macro avg       0.57      0.51      0.49     88572
# weighted avg       0.86      0.92      0.88     88572
#
#
# Decision tree Results:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92     81420
#            1       0.14      0.15      0.14      7152
#
#     accuracy                           0.85     88572
#    macro avg       0.53      0.53      0.53     88572
# weighted avg       0.86      0.85      0.86     88572

# %%
labels=['Naive Bayes','Decision tree','Logistic Regresion']
fpr =[]
tpr = []
mod=''

#Complete el código
for i in range(len(labels)):
  fpr.append(0)
  tpr.append(0)
  if i==0:
    y_pred2 = gnb.predict_proba(X_test)
    mod='GNB'
  elif i==1:
    y_pred2 = dtc.predict_proba(X_test)
    mod='DTC'
  else:
    y_pred2 = rl.predict_proba(X_test)
    mod='LR'
  score = y_pred2[:,0]-y_pred2[:,1]
  fpr[i], tpr[i],_ = roc_curve(y_test,score)
  roc_auc = 1 - auc(fpr[i], tpr[i])
  plt.plot(tpr[i],fpr[i],lw=2, label='ROC curve {} (area = {})'.format(mod,round(roc_auc,4)))
  plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('ROC curve')
  plt.legend(loc="lower right")
  plt.grid()
plt.show()

# %% [markdown]
# # 7.Evaluación sobre el conjunto de Test

# %%
plot_confusion_matrix(dtc, X_test, y_test,cmap=plt.cm.Blues,normalize='true');
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_dtc_pred).ravel()
sensitivity = tp / (tp+fn)
sensitivity
# Out:
# 0.1524049217002237

# %% [markdown]
# Curva ROC

# %%
y_pred2=gnb.predict_proba(X_test)

# %%
fpr =[]
tpr = []
fpr.append(0)
tpr.append(0)
score = y_pred2[:,0]-y_pred2[:,1]
fpr, tpr,_ = roc_curve(y_test,score)
roc_auc = 1 - auc(fpr, tpr)
plt.plot(tpr,fpr,lw=2)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.grid()
plt.show()
print('ROC curve Naive Bayes (area = {})'.format(round(roc_auc,4)))
# Out:
# ROC curve Naive Bayes (area = 0.619)

# %% [markdown]
# # 9.Observaciones a tener en cuenta a futuro para mejorar el performance del modelo

# %% [markdown]
# * Se identifica que aunque el accuracy y el recall daban buenos resultados, con la matriz de confusión, vemos que los modelos no predicen de una manera adecuada.
# * Teniendo en cuenta la alta dimensionalidad del dataset original, sería interesante realizar un PCA.
# * Probar resultados utilizando un escalamiento de las variables, sea mediante el método MinMax o estandarizado.
# * Probar los resultados si se realiza SMOTE en la variable TARGET
# * Hacer optimización de hiperparametros de al menos 2 modelos que hayan tenido los mejores resultados en la métrica seleccionada
# * Realizar cross validation durante el proceso de entrenamiento para su correcta validación de los hiperparametros seleccionados
